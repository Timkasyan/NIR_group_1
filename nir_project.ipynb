# %%
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.parser import parse

# %%
FILEPATH_2020 = "with_closed_ations_as________select_app_2020_X5_STORES.csv"
FILEPATH_2019 = "with_closed_ations_as________select_app_2019_X5_STORES.csv"
FILEPATH_2018 = "with_closed_ations_as________select_app_2018_X5_STORES.csv"
df = pd.read_csv(FILEPATH_2019)
# Out:
# /home/lev/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df = df[df['position_name'] == 'Продавец-кассир']
df = df[df['is_active_action'] == True]
df = df.drop('is_active_action', axis=1)
df['action_date'] = df['action_date'].str[:19]
df['action_date'] = pd.to_datetime(df['action_date'], format="%Y-%m-%d %H:%M:%S")

# %%
df
# Out:
#         id_applicant  id_partner    id_log  department_id  \
# 3245         4774172     3835783        -1          31992
# 214958       4774172     3835783  26666690          31992
# 214959       4774172     3835783  26666679          31992
# 214960       4774172     3835783  26649216          31992
#
#                           action_date          stage_name  \
# 3245    2020-03-18 07:09:13.105863+00  Создание кандидата
# 214958  2020-03-26 14:48:20.719833+00          Оформление
# 214959  2020-03-26 14:48:05.111505+00          Оформление
# 214960  2020-03-26 10:03:58.809604+00          Оформление
#
#                                    activity_name  \
# 3245                                         NaN
# 214958                  Узнать результаты приема
# 214959  Предоставить обратную связь по кандидату
# 214960  Предоставить обратную связь по кандидату
#
#                               result_name    position_name  is_active_action  \
# ...

# %%
df[df['is_active_action'] == False]
# Out:
#         id_applicant  id_partner  id_log  department_id  \
# 341          4808717     3819705      -1          11867
# 877          4810706     3854736      -1           6325
# 1015         4814888     2488253      -1          11037
# 1096         4814717     3856712      -1          32815
# 1414         4801029     3849575      -1          11134
# ...              ...         ...     ...            ...
# 739486       4729069     2317788      -1          30844
# 739534       4790647     3582921      -1          31034
# 739541       4669579     2471869      -1          31087
# 739545       4606237     3093534      -1          31150
# 739663       4820831     3470886      -1          31990
#
#                           action_date          stage_name  \
# 341     2020-03-25 16:30:40.955961+00  Создание кандидата
# 877     2020-03-26 10:11:16.009413+00  Создание кандидата
# 1015    2020-03-27 09:13:33.870314+00  Создание кандидата
# ...

# %%
df[df['is_active_action'] == False]

# %%
df['stage_name'].unique()
# Out:
# array(['Создание кандидата', 'Интервью с руководителем', 'Обработка',
#        'Оформление', 'Смена вакансии', 'СБ', 'Не прошел СБ',
#        'Мы отказали', 'Выход на работу', 'Отказался', 'Резерв',
#        'Черный список'], dtype=object)

# %%
# df[df['stage_name'] == 'Выход на работу']

# %%
# df[df['stage_name'] == 'Оформление']

# %%
df['activity_name'].unique()
# Out:
# array([nan, 'Узнать результаты интервью с руководителем',
#        'Назначить интервью с руководителем', 'Проверка формы обращения',
#        'Провести первичную обработку',
#        'Предоставить обратную связь по кандидату',
#        'Назначить время на оформление', 'Узнать результаты СБ',
#        'Подготовить анкету кандидата', 'Узнать результаты приема',
#        'Вывести из черного списка'], dtype=object)

# %%
df['result_name'].unique()
# Out:
# array([nan, 'Отказ кандидата', 'Не резерв', 'Подходит', 'Не подходит',
#        'ОС не предоставлена руководителем', 'Отказ руководителя',
#        'Недозвон', 'Перенос звонка', 'Встреча назначена', 'Подготовлена',
#        'Резерв', 'Принят', 'ОС предоставлена руководителем',
#        'Время назначено', 'Нет обратной связи от руководителя',
#        'В белый список', 'Перенос кандидата', 'Нет обратной связи',
#        'Не принят', 'Черный список', 'Перенос руководителя',
#        'Уточнение данных'], dtype=object)

# %%
df[df['id_applicant'] == 4798973]
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 7099         4798973     1387757        -1          35388 2020-03-24 10:39:37
# 314224       4798973     1387757  26577377          35388 2020-03-24 10:39:49
# 314225       4798973     1387757  26577381          35388 2020-03-24 10:39:50
# 314226       4798973     1387757  26577405          35388 2020-03-24 10:40:07
# 314227       4798973     1387757  26676916          35388 2020-03-26 19:08:40
#
#                       stage_name                       activity_name  \
# 7099          Создание кандидата                                 NaN
# 314224                 Обработка        Провести первичную обработку
# 314225                 Обработка            Проверка формы обращения
# 314226  Интервью с руководителем  Назначить интервью с руководителем
# 314227            Смена вакансии                                 NaN
#
#            result_name    position_name  is_open_action
# ...

# %%
df_new = df[['id_applicant','stage_name','activity_name','result_name']]
df_new = df_new.sort_values('id_applicant')
df_new = df_new[df_new['stage_name'] != 'Создание кандидата']

# %%
df_new.to_csv('unique2.csv')

# %%
df_new = df[['stage_name','activity_name','result_name']]
df_new = df_new.drop_duplicates().sort_values('stage_name')

# %%
df_new.to_csv('unique.csv')

# %%
df.groupby('id_applicant').count().sort_values('action_date')
# Out:
#               id_partner  id_log  department_id  action_date  stage_name  \
# id_applicant
# 4461761                1       1              1            1           1
# 4687013                1       1              1            1           1
# 4687007                1       1              1            1           1
# 4687006                1       1              1            1           1
# 4687003                1       1              1            1           1
# ...                  ...     ...            ...          ...         ...
# 4811435               29      29             29           29          29
# 4814936               30      30             30           30          30
# 4700471               31      31             31           31          31
# 4788781               31      31             31           31          31
# 4784167               34      34             34           34          34
#
#               activity_name  result_name  position_name  is_open_action
# ...

# %%
df[df['id_applicant'] == 4784167].drop(['id_log', 'is_open_action', 'position_name'], axis=1).sort_values('action_date')
# Out:
#         id_applicant  id_partner  department_id         action_date  \
# 182109       4784167     3339623          49607 2020-03-19 16:25:55
# 625663       4784167     3339623          49607 2020-03-19 16:26:12
# 625664       4784167     3339623          49607 2020-03-19 16:26:13
# 625665       4784167     3339623          49607 2020-03-19 16:26:44
# 625666       4784167     3339623          49607 2020-03-20 15:44:50
# 625667       4784167     3339623          49607 2020-03-20 15:44:51
# 625668       4784167     3339623          49607 2020-03-20 17:27:26
# 625669       4784167     3339623          49607 2020-03-20 17:27:27
# 625670       4784167     3339623          49607 2020-03-21 17:49:34
# 625680       4784167     3339623          49607 2020-03-24 11:16:57
# 625671       4784167     3339623          49607 2020-03-25 16:23:06
# 625672       4784167     3339623          49607 2020-03-26 17:24:45
# 625673       4784167     3339623          49607 2020-03-27 12:29:12
# ...

# %%
df[df['id_applicant'] == 4700471].drop(['id_log', 'is_open_action', 'position_name'], axis=1).sort_values('action_date')
# Out:
#         id_applicant  id_partner  department_id         action_date  \
# 128776       4700471     3797151          30806 2020-02-28 09:26:22
# 397218       4700471     3797151          30806 2020-02-28 09:26:31
# 397243       4700471     3797151          30806 2020-02-28 09:26:33
# 397219       4700471     3797151          30806 2020-02-28 09:26:34
# 397220       4700471     3797151          30806 2020-02-28 09:26:36
# 397221       4700471     3797151          30806 2020-02-28 09:26:37
# 397222       4700471     3797151          30806 2020-02-28 10:55:17
# 397240       4700471     3797151          30806 2020-02-28 10:55:18
# 397223       4700471     3797151          30806 2020-02-28 15:47:48
# 397224       4700471     3797151          30806 2020-02-28 17:35:11
# 397225       4700471     3797151          30806 2020-02-29 12:46:38
# 397226       4700471     3797151          30806 2020-03-03 12:00:01
# 397227       4700471     3797151          30806 2020-03-03 12:14:28
# ...

# %%
# df[(df['activity_name'] == 'Узнать результаты СБ') & (df['result_name'] == 'Подготовлена')]

# %%
df[df['id_applicant'] == 4814936].drop(['id_log','is_open_action', 'position_name'], axis=1).sort_values('action_date')
# Out:
#         id_applicant  id_partner  department_id         action_date  \
# 181887       4814936     3856819          12114 2020-03-27 09:21:02
# 673967       4814936     3856819          12114 2020-03-27 09:21:22
# 673966       4814936     3856819          12114 2020-03-27 09:21:23
# 673965       4814936     3856819          12114 2020-03-27 09:21:34
# 673964       4814936     3856819          12114 2020-03-27 14:30:20
# 673963       4814936     3856819          12114 2020-03-27 14:30:40
# 673962       4814936     3856819          12114 2020-03-29 12:42:38
# 673961       4814936     3856819          12114 2020-03-29 12:42:51
# 673960       4814936     3856819          12114 2020-03-31 16:12:17
# 673959       4814936     3856819          12114 2020-04-01 14:01:52
# 673958       4814936     3856819          12114 2020-04-01 15:32:06
# 673957       4814936     3856819          12114 2020-04-01 15:32:12
# 673956       4814936     3856819          12114 2020-04-01 15:32:15
# ...

# %%
# df[(df['activity_name'] == 'Предоставить обратную связь по кандидату') & (df['result_name'].isnull())]

# %%
df[df['id_applicant'] == 4845963].drop(['id_log', 'is_open_action', 'position_name'], axis=1).sort_values(['action_date', 'activity_name'])
# Out:
#         id_applicant  id_partner  department_id         action_date  \
# 189055       4845963     3871526          43717 2020-04-05 12:23:44
# 236528       4845963     3871526          43717 2020-04-05 12:23:52
# 236527       4845963     3871526          43717 2020-04-05 12:23:52
# 236526       4845963     3871526          43717 2020-04-05 12:24:02
# 236525       4845963     3871526          43717 2020-04-12 13:58:59
# 236524       4845963     3871526          43717 2020-04-13 19:31:52
# 736413       4845963     3871526          43717 2020-04-23 16:26:11
#
#                       stage_name                               activity_name  \
# 189055        Создание кандидата                                         NaN
# 236528                 Обработка                    Проверка формы обращения
# 236527                 Обработка                Провести первичную обработку
# 236526  Интервью с руководителем          Назначить интервью с руководителем
# ...

# %%
# df[df['id_applicant'] == 4811435].drop(['id_log', 'is_active_action', 'is_open_action', 'position_name'], axis=1).sort_values('action_date')

# %%
df_new = df[['stage_name','activity_name','result_name']]
df_new = df_new.drop_duplicates().sort_values('stage_name')
df_new = df_new.reset_index(drop=True)
df_new
# Out:
#                    stage_name                             activity_name  \
# 0             Выход на работу                                       NaN
# 1             Выход на работу                                       NaN
# 2             Выход на работу                                       NaN
# 3    Интервью с руководителем  Предоставить обратную связь по кандидату
# 4    Интервью с руководителем  Предоставить обратную связь по кандидату
# ..                        ...                                       ...
# 99             Смена вакансии                                       NaN
# 100            Смена вакансии                                       NaN
# 101            Смена вакансии                                       NaN
# 102        Создание кандидата                                       NaN
# 103             Черный список                 Вывести из черного списка
#
#                            result_name
# 0                             Недозвон
# ...

# %%
df_new = df[['stage_name','activity_name','result_name']]
df_new = df_new.drop_duplicates().sort_values('stage_name')
df_new = df_new.reset_index(drop=True)
df_new
df_copy = df.copy()
df_copy[['stage_name', 'activity_name', 'result_name']] = df_copy[['stage_name', 'activity_name', 'result_name']].fillna('')
df_new[['stage_name', 'activity_name', 'result_name']] = df_new[['stage_name', 'activity_name', 'result_name']].fillna('')
df_new['count'] = 0
# df[df['stage_name'] == "Выход на работу"].shape[0]
for index, row in df_new.iterrows():
    val = df_copy[(df_copy['stage_name'] == row['stage_name']) & (df_copy['activity_name'] == row['activity_name']) & (df_copy['result_name'] == row['result_name'])].shape[0]
    df_new.at[index, 'count'] = val
df_new
# Out:
#                    stage_name                             activity_name  \
# 0             Выход на работу
# 1             Выход на работу
# 2             Выход на работу
# 3    Интервью с руководителем  Предоставить обратную связь по кандидату
# 4    Интервью с руководителем  Предоставить обратную связь по кандидату
# ..                        ...                                       ...
# 99             Смена вакансии
# 100            Смена вакансии
# 101            Смена вакансии
# 102        Создание кандидата
# 103             Черный список                 Вывести из черного списка
#
#                            result_name   count
# 0                             Недозвон       1
# 1                      Отказ кандидата       2
# 2    ОС не предоставлена руководителем      16
# 3                    Встреча назначена      52
# 4       ОС предоставлена руководителем    1099
# ..                                 ...     ...
# 99   ОС не предоставлена руководителем       4
# ...

# %%
df_new.sort_values('count').to_csv('unique_count.csv')

# %%
df_new.sort_values('stage_name').to_csv('unique_count2.csv')

# %%
# df[df['stage_name'] == 'Выход на работу']

# %%
df[df['id_applicant'] == 4824789].drop(['id_log','is_open_action', 'position_name'], axis=1).sort_values('action_date')
# Out:
#         id_applicant  id_partner  department_id         action_date  \
# 182053       4824789     3861710          30408 2020-03-31 08:00:21
# 261153       4824789     3861710          30408 2020-03-31 08:00:30
# 261154       4824789     3861710          30408 2020-03-31 08:00:30
# 261152       4824789     3861710          30408 2020-03-31 08:00:31
# 261151       4824789     3861710          30408 2020-03-31 08:00:32
# 261150       4824789     3861710          30408 2020-03-31 08:00:32
# 261148       4824789     3861710          30408 2020-03-31 10:02:27
# 261149       4824789     3861710          30408 2020-03-31 10:02:28
# 261147       4824789     3861710          30408 2020-04-01 09:19:48
# 261146       4824789     3861710          30408 2020-04-01 09:19:51
# 261145       4824789     3861710          30408 2020-04-01 16:04:32
# 261144       4824789     3861710          30408 2020-04-02 14:06:37
# 261143       4824789     3861710          30408 2020-04-03 12:04:29
# ...

# %%
# df[df['id_applicant'] == 4782054].drop(['id_log','is_open_action', 'position_name'], axis=1).sort_values('action_date')

# %%
# df[df['id_applicant'] == 4796626].drop(['is_open_action', 'position_name'], axis=1).sort_values('action_date')

# %%
# df[df['id_applicant'] == 4796626].drop(['is_open_action', 'position_name'], axis=1).sort_values('action_date')

# %%
# df[df['id_applicant'] == 4818196].drop(['is_open_action', 'position_name'], axis=1).sort_values('action_date')

# %%
# df[df['stage_name'] == 'Мы отказали']

# %%
# df[df['id_applicant'] == 4803377].drop(['is_open_action', 'position_name'], axis=1).sort_values('action_date')

# %%
# df[(df['stage_name'] == 'Интервью с руководителем') & (df['activity_name'] == 'Предоставить обратную связь по кандидату')]

# %%
# df[(df['stage_name'] == 'Интервью с руководителем') & (df['activity_name'] == 'Узнать результаты интервью с руководителем')]

# %%
# df[df['id_applicant'] == 4848496].drop(['is_open_action', 'position_name'], axis=1).sort_values('action_date')

# %%
df.loc[(df['stage_name'] == 'Интервью с руководителем') & (df['activity_name'] == 'Предоставить обратную связь по кандидату'), 'activity_name'] = 'Узнать результаты интервью с руководителем'

# %%
def generate_unique_csv():
    df_new = df[['stage_name','activity_name','result_name']]
    df_new = df_new.drop_duplicates().sort_values('stage_name')
    df_new = df_new.reset_index(drop=True)
    df_new
    df_copy = df.copy()
    df_copy[['stage_name', 'activity_name', 'result_name']] = df_copy[['stage_name', 'activity_name', 'result_name']].fillna('')
    df_new[['stage_name', 'activity_name', 'result_name']] = df_new[['stage_name', 'activity_name', 'result_name']].fillna('')
    df_new['count'] = 0
    for index, row in df_new.iterrows():
        val = df_copy[(df_copy['stage_name'] == row['stage_name']) & (df_copy['activity_name'] == row['activity_name']) & (df_copy['result_name'] == row['result_name'])].shape[0]
        df_new.at[index, 'count'] = val
    df_new.sort_values('stage_name').to_csv('unique_count2.csv')
    return df_new

def clientInfo(df, id):
    return df[df['id_applicant'] == id].drop(['is_open_action', 'position_name'], axis=1).sort_values('action_date')

# %%
df.loc[(df['stage_name'] == 'Интервью с руководителем') & (df['activity_name'] == 'Узнать результаты интервью с руководителем') & (df['result_name'] == 'Нет обратной связи от руководителя'), 'result_name'] = 'ОС не предоставлена руководителем'

# %%
df_new = generate_unique_csv()

# %%
df_new[(df_new['stage_name'] == 'Интервью с руководителем') & (df_new['activity_name'] == 'Узнать результаты интервью с руководителем')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7bb15f261466> in <module>
# ----> 1 df_new[(df_new['stage_name'] == 'Интервью с руководителем') & (df_new['activity_name'] == 'Узнать результаты интервью с руководителем')]
#
# NameError: name 'df_new' is not defined

# %%
df.loc[(df['stage_name'] == 'Интервью с руководителем') & (df['activity_name'] == 'Узнать результаты интервью с руководителем') & (df['result_name'] == 'Перенос руководителя'), 'result_name'] = 'Перенос звонка'

# %%
df_new = generate_unique_csv()
df_new[(df_new['stage_name'] == 'Интервью с руководителем') & (df_new['activity_name'] == 'Узнать результаты интервью с руководителем')]
# Out:
#                   stage_name                               activity_name  \
# 5   Интервью с руководителем  Узнать результаты интервью с руководителем
# 7   Интервью с руководителем  Узнать результаты интервью с руководителем
# 9   Интервью с руководителем  Узнать результаты интервью с руководителем
# 10  Интервью с руководителем  Узнать результаты интервью с руководителем
# 13  Интервью с руководителем  Узнать результаты интервью с руководителем
# 14  Интервью с руководителем  Узнать результаты интервью с руководителем
# 15  Интервью с руководителем  Узнать результаты интервью с руководителем
# 16  Интервью с руководителем  Узнать результаты интервью с руководителем
# 17  Интервью с руководителем  Узнать результаты интервью с руководителем
# 19  Интервью с руководителем  Узнать результаты интервью с руководителем
# 21  Интервью с руководителем  Узнать результаты интервью с руководителем
# 22  Интервью с руководителем  Узнать результаты интервью с руководителем
#
# ...

# %%
df.loc[(df['stage_name'] == 'Интервью с руководителем') & (df['activity_name'] == 'Назначить интервью с руководителем') & (df['result_name'] == 'Перенос кандидата'), 'result_name'] = 'Перенос звонка'

# %%
df_new = generate_unique_csv()

# %%
# df[(df['stage_name'] == 'Интервью с руководителем') & (df['result_name'] == 'ОС предоставлена руководителем')]

# %%
# df[df['id_applicant'] == 4799489].drop(['is_open_action', 'position_name'], axis=1).sort_values('action_date')

# %%
df = df.drop(df[(df['stage_name'] == 'Интервью с руководителем') & (df['result_name'] == 'ОС предоставлена руководителем')].index)

# %%
df_new = generate_unique_csv()

# %%
df
# Out:
#         id_applicant  id_partner  id_log  department_id         action_date  \
# 0            4797513     3847682      -1           7335 2020-03-23 19:57:25
# 3            4788965     3843286      -1          10613 2020-03-20 16:09:34
# 4            4777310     2372866      -1          45445 2020-03-18 13:53:36
# 11           4798971     1253935      -1           9851 2020-03-24 10:39:28
# 13           4637426     3352131      -1           7640 2020-02-13 12:44:35
# ...              ...         ...     ...            ...                 ...
# 739675       4825142     2952699      -1          32061 2020-04-23 16:26:11
# 739676       4736341      936507      -1          32061 2020-04-23 16:26:11
# 739678       4782853     2753502      -1          32110 2020-04-23 16:26:11
# 739679       4769924     3823657      -1          32110 2020-04-23 16:26:11
# 739680       4683816      862865      -1          32093 2020-04-23 16:26:11
#
# ...

# %%
# df[(df['stage_name'] == 'Интервью с руководителем') & (df['activity_name'] == 'Узнать результаты интервью с руководителем') & (df['result_name'] == 'Встреча назначена')]

# %%
# df[df['id_applicant'] == 4837354].drop(['is_open_action', 'position_name'], axis=1).sort_values('action_date')

# %%
# Можно дропнуть встреча назначена при узнавании результатов

# %%
# df[(df['stage_name'] == 'Интервью с руководителем') & (df['activity_name'] == 'Узнать результаты интервью с руководителем') & (df['result_name'].isnull())]

# %%
# df[df['id_applicant'] == 4869996].drop(['is_open_action', 'position_name'], axis=1).sort_values('action_date')
# Если в каком-то действии в конце Nan, то это дроп чувака

# %%
df[(df['stage_name'] == 'Интервью с руководителем') & (df['activity_name'] == 'Назначить интервью с руководителем') & (df['result_name'] == 'Подходит')]
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 218741       4811950     3695890  26657761          25427 2020-03-26 12:04:50
# 220799       4849738     3877121  26890280          49708 2020-04-06 13:31:42
# 221034       4835052     3867697  26811681          23921 2020-04-02 13:18:21
# 222676       4873437     3890759  27027004           7979 2020-04-10 14:51:48
# 222701       4846359     3874900  26874907          12459 2020-04-05 15:56:32
# ...              ...         ...       ...            ...                 ...
# 686066       4883300     3895331  27087805          25209 2020-04-13 15:32:50
# 687226       4862908     3884746  26963845          49767 2020-04-08 15:22:31
# 692365       4886031     3896869  27103320           9332 2020-04-14 10:13:00
# 694445       4842757     2846900  26849202          35130 2020-04-03 18:02:24
# 694773       4885247     1956260  27099515          12871 2020-04-14 08:19:25
#
# ...

# %%
# df[df['id_applicant'] == 4873437].drop(['is_open_action', 'position_name'], axis=1).sort_values('action_date')

# %%
df = df.drop(df[(df['stage_name'] == 'Интервью с руководителем') & (df['activity_name'] == 'Назначить интервью с руководителем') & (df['result_name'] == 'Подходит')].index)

# %%
df_new = generate_unique_csv()

# %%
df[df['stage_name'] == 'Мы отказали']
# В основном это лишний мусор, но решил пока оставить. Это состояние, куда переводят после интервью или СБ
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 221885       4803377     3850828  26680522          24908 2020-03-27 09:21:14
# 287899       4807811      948072  26729448          32643 2020-03-30 12:32:10
# 333046       4813971     2975040  26697563          12973 2020-03-27 14:35:50
# 464338       4760133     3605084  26672709          25514 2020-03-26 16:40:37
# 618748       4825168     3585894  26799123          46421 2020-04-02 07:58:58
# 664795       4812845     3855833  26731791           9757 2020-03-30 13:26:03
# 694423       4822095     2515323  26940860          28541 2020-04-08 06:31:48
#
#          stage_name activity_name                         result_name  \
# 221885  Мы отказали           NaN  Нет обратной связи от руководителя
# 287899  Мы отказали           NaN                      В белый список
# 333046  Мы отказали           NaN  Нет обратной связи от руководителя
# ...

# %%
clientInfo(df, 4803377)
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 183378       4803377     3850828        -1          24908 2020-03-24 19:07:07
# 221887       4803377     3850828  26669376          24908 2020-03-26 15:53:51
# 221886       4803377     3850828  26680483          24908 2020-03-27 09:20:12
# 221885       4803377     3850828  26680522          24908 2020-03-27 09:21:14
# 221883       4803377     3850828  26694305          24908 2020-03-27 13:39:26
# 221882       4803377     3850828  26694314          24908 2020-03-27 13:39:33
# 221881       4803377     3850828  26694323          24908 2020-03-27 13:39:46
# 221880       4803377     3850828  26694324          24908 2020-03-27 13:39:47
# 221879       4803377     3850828  26705446          24908 2020-03-27 17:37:52
# 221878       4803377     3850828  26780326          24908 2020-04-01 09:10:51
# 221877       4803377     3850828  27064732          24908 2020-04-12 15:12:29
# ...

# %%
df[(df['stage_name'] == 'Обработка') & (df['activity_name'] == 'Проверка формы обращения') & (df['result_name'] == 'Подходит')]
# Out:
# Empty DataFrame
# Columns: [id_applicant, id_partner, id_log, department_id, action_date, stage_name, activity_name, result_name, position_name, is_open_action]
# Index: []

# %%
# clientInfo(df, 4855286)

# %%
df = df.drop(df[(df['stage_name'] == 'Обработка') & (df['activity_name'] == 'Проверка формы обращения') & (df['result_name'] == 'Подходит')].index)

# %%
df_new = generate_unique_csv()

# %%
df[(df['stage_name'] == 'Оформление') & (df['activity_name'] == 'Узнать результаты приема')]
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 214909       4784277     3840984  26664817           5960 2020-03-26 14:13:07
# 214910       4784277     3840984  26639308           5960 2020-03-25 17:35:49
# 214958       4774172     3835783  26666690          31992 2020-03-26 14:48:20
# 214962       4813502     3821610  26668701          18141 2020-03-26 15:39:35
# 214980       4813678     2057903  26669783          31462 2020-03-26 16:01:07
# ...              ...         ...       ...            ...                 ...
# 739646       4859722     3757095        -1          32011 2020-04-23 16:26:11
# 739647       4846458     3831915        -1          32011 2020-04-23 16:26:11
# 739660       4862004     3884234        -1          31960 2020-04-23 16:26:11
# 739661       4847420     3792798        -1          31960 2020-04-23 16:26:11
# 739674       4858661     3882286        -1          32061 2020-04-23 16:26:11
#
# ...

# %%
# clientInfo(df, 4859722)

# %%
df.loc[(df['stage_name'] == 'Оформление') & (df['activity_name'] == 'Узнать результаты приема'), 'activity_name'] = 'Узнать результаты интервью с руководителем'

# %%
df[(df['stage_name'] == 'Смена вакансии')]
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 214838       4799096     3388458  26642796          30059 2020-03-26 08:05:14
# 214898       4795061     3742188  26650264          11473 2020-03-26 10:18:28
# 214902       4812039     2058461  26689072          34670 2020-03-27 12:00:30
# 214928       4805065     3851754  26687231          31603 2020-03-27 11:28:02
# 214934       4810900     3854856  26689533          24877 2020-03-27 12:03:08
# ...              ...         ...       ...            ...                 ...
# 704549       4826495     3848893  26823299           9400 2020-04-02 18:14:28
# 704595       4797098     3847494  26684028          11389 2020-03-27 10:29:21
# 704608       4799489     3803952  26732475          19050 2020-03-30 13:39:29
# 704617       4829912     3864508  26802382          10685 2020-04-02 09:47:46
# 704646       4828062     2923389  26772773          25608 2020-03-31 16:15:31
#
# ...

# %%
clientInfo(df, 4799096)
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 1808         4799096     3388458        -1          30059 2020-03-24 10:52:47
# 214837       4799096     3388458  26578035          30059 2020-03-24 10:53:03
# 214834       4799096     3388458  26578038          30059 2020-03-24 10:53:04
# 214839       4799096     3388458  26578040          30059 2020-03-24 10:53:06
# 214835       4799096     3388458  26578046          30059 2020-03-24 10:53:16
# 214836       4799096     3388458  26623129          30059 2020-03-25 13:15:22
# 214838       4799096     3388458  26642796          30059 2020-03-26 08:05:14
#
#                       stage_name                               activity_name  \
# 1808          Создание кандидата                                         NaN
# 214837                 Обработка                Провести первичную обработку
# 214834                 Обработка                    Проверка формы обращения
# ...

# %%
df[(df['stage_name'] == 'Не прошел СБ')]
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 215323       4509821     3694092  26973768           6552 2020-04-09 06:59:29
# 215376       4484438     3679681  26907121          20375 2020-04-07 06:59:25
# 215456       4490980     3597781  26876696          30511 2020-04-06 08:00:36
# 215457       4485973     3487032  26876692          10795 2020-04-06 08:00:31
# 215475       4496296     3655253  26974574          12807 2020-04-09 07:59:13
# ...              ...         ...       ...            ...                 ...
# 739675       4825142     2952699        -1          32061 2020-04-23 16:26:11
# 739676       4736341      936507        -1          32061 2020-04-23 16:26:11
# 739678       4782853     2753502        -1          32110 2020-04-23 16:26:11
# 739679       4769924     3823657        -1          32110 2020-04-23 16:26:11
# 739680       4683816      862865        -1          32093 2020-04-23 16:26:11
#
# ...

# %%
clientInfo(df, 4782853)
# Out:
#         id_applicant  id_partner  id_log  department_id         action_date  \
# 214300       4782853     2753502      -1          32110 2020-03-19 13:41:49
# 739678       4782853     2753502      -1          32110 2020-04-23 16:26:11
#
#                 stage_name              activity_name result_name
# 214300  Создание кандидата                        NaN         NaN
# 739678        Не прошел СБ  Вывести из черного списка         NaN

# %%
df[(df['stage_name'] == 'Черный список')]
# Out:
#         id_applicant  id_partner  id_log  department_id         action_date  \
# 704772       4538990     3002793      -1          42954 2020-04-23 16:26:11
# 704907       4539272     2098346      -1          42954 2020-04-23 16:26:11
# 704922       4758392     3197557      -1          10708 2020-04-23 16:26:11
# 705423       4542608     3622649      -1          30991 2020-04-23 16:26:11
# 705424       4541709     2474617      -1          30991 2020-04-23 16:26:11
# 705425       4541218     2750312      -1          30991 2020-04-23 16:26:11
# 706616       4829525     3864281      -1          11890 2020-04-23 16:26:11
# 706814       4814273     3516801      -1          36545 2020-04-23 16:26:11
# 707163       4822333     3824380      -1           7947 2020-04-23 16:26:11
# 707334       4832169     3290102      -1          11755 2020-04-23 16:26:11
# 709552       4847557     3873113      -1          11448 2020-04-23 16:26:11
# ...

# %%
clientInfo(df, 4579388)
# Out:
#         id_applicant  id_partner  id_log  department_id         action_date  \
# 130893       4579388     3652507      -1          48245 2020-01-31 17:23:54
# 722568       4579388     3652507      -1          48245 2020-04-23 16:26:11
#
#                 stage_name              activity_name result_name
# 130893  Создание кандидата                        NaN         NaN
# 722568       Черный список  Вывести из черного списка         NaN

# %%
df[(df['stage_name'] == 'Оформление') & (df['result_name'] == 'Принят')]
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 214958       4774172     3835783  26666690          31992 2020-03-26 14:48:20
# 214962       4813502     3821610  26668701          18141 2020-03-26 15:39:35
# 214980       4813678     2057903  26669783          31462 2020-03-26 16:01:07
# 215047       4813843     3822462  26671477          30354 2020-03-26 16:21:38
# 215065       4766031     3831548  26674667          31760 2020-03-26 17:16:26
# ...              ...         ...       ...            ...                 ...
# 704170       4854560     3855417  26915732          49671 2020-04-07 11:05:40
# 704241       4883157     3860226  27087224          10660 2020-04-13 15:18:28
# 704254       4846293     3856487  27087777           7649 2020-04-13 15:32:12
# 704464       4864742     1593647  27105932          23665 2020-04-14 11:07:42
# 704686       4786759     3842225  26635619           6260 2020-03-25 16:28:25
#
# ...

# %%
clientInfo(df, 4766031)
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 6735         4766031     3831548        -1          31760 2020-03-16 13:23:00
# 215067       4766031     3831548  26657648          31760 2020-03-26 12:04:07
# 215066       4766031     3831548  26674666          31760 2020-03-26 17:16:21
# 215065       4766031     3831548  26674667          31760 2020-03-26 17:16:26
#
#                 stage_name                             activity_name  \
# 6735    Создание кандидата                                       NaN
# 215067          Оформление  Предоставить обратную связь по кандидату
# 215066          Оформление  Предоставить обратную связь по кандидату
# 215065          Оформление                  Узнать результаты приема
#
#                               result_name
# 6735                                  NaN
# 215067  ОС не предоставлена руководителем
# 215066     ОС предоставлена руководителем
# 215065                             Принят

# %%
df[(df['department_id'] == 31760)].sort_values('')
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 6735         4766031     3831548        -1          31760 2020-03-16 13:23:00
# 1083         4793468     3768121        -1          31760 2020-03-23 11:43:44
# 20787        4811430     2345146        -1          31760 2020-03-26 11:16:01
# 574651       4811430     2345146  26654161          31760 2020-03-26 11:16:16
# 574650       4811430     2345146  26654162          31760 2020-03-26 11:16:18
# 574649       4811430     2345146  26654185          31760 2020-03-26 11:16:35
# 215067       4766031     3831548  26657648          31760 2020-03-26 12:04:07
# 293788       4793468     3768121  26674256          31760 2020-03-26 17:08:17
# 215066       4766031     3831548  26674666          31760 2020-03-26 17:16:21
# 215065       4766031     3831548  26674667          31760 2020-03-26 17:16:26
# 574648       4811430     2345146  26675787          31760 2020-03-26 17:38:54
# ...

# %%
clientInfo(df, 4866765)
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 25600        4866765     3885394        -1          31760 2020-04-09 12:09:23
# 371236       4866765     3885394  26986701          31760 2020-04-09 12:10:03
# 371235       4866765     3885394  26986703          31760 2020-04-09 12:10:05
# 371234       4866765     3885394  26986705          31760 2020-04-09 12:10:06
# 371233       4866765     3885394  26986706          31760 2020-04-09 12:10:07
# 371232       4866765     3885394  26986707          31760 2020-04-09 12:10:08
# 371231       4866765     3885394  26993008          31760 2020-04-09 13:49:06
# 706442       4866765     3885394        -1          31760 2020-04-23 16:26:11
#
#                       stage_name                               activity_name  \
# 25600         Создание кандидата                                         NaN
# 371236                 Обработка                Провести первичную обработку
# ...

# %%
df[(df['stage_name'] == 'Смена вакансии') & (df['position_name'] == 'Продавец-кассир')].head(30)
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 214838       4799096     3388458  26642796          30059 2020-03-26 08:05:14
# 214898       4795061     3742188  26650264          11473 2020-03-26 10:18:28
# 214902       4812039     2058461  26689072          34670 2020-03-27 12:00:30
# 214928       4805065     3851754  26687231          31603 2020-03-27 11:28:02
# 214934       4810900     3854856  26689533          24877 2020-03-27 12:03:08
# 214977       4798209     3848067  26644999          33667 2020-03-26 09:07:52
# 214997       4801837     3847036  26647473          12823 2020-03-26 09:44:08
# 215017       4783145     3840392  26670796          20066 2020-03-26 16:10:23
# 215169       4812656     3843484  26707605          31401 2020-03-28 09:19:17
# 215183       4813645     3676612  26708369          12871 2020-03-28 11:15:21
# 215294       4805112     3847751  26715261           9724 2020-03-29 14:32:06
# ...

# %%
# clientInfo(df, 4799489)
df[df['id_applicant'] == 4831592].sort_values('action_date')
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 36831        4831592     3865560        -1           9673 2020-04-01 14:22:45
# 216242       4831592     3865560  26791885           9673 2020-04-01 14:22:56
# 216243       4831592     3865560  26791887           9673 2020-04-01 14:22:57
# 216244       4831592     3865560  26791903           9673 2020-04-01 14:23:06
# 216245       4831592     3865560  26825629           9673 2020-04-03 08:41:01
#
#                       stage_name                       activity_name  \
# 36831         Создание кандидата                                 NaN
# 216242                 Обработка        Провести первичную обработку
# 216243                 Обработка            Проверка формы обращения
# 216244  Интервью с руководителем  Назначить интервью с руководителем
# 216245            Смена вакансии                                 NaN
#
#               result_name    position_name  is_open_action
# ...

# %%
df[(df['department_id'] == 11473)].sort_values('action_date')
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 44660        4760317     3828579        -1          11473 2020-03-13 16:36:08
# 2225         4795061     3742188        -1          11473 2020-03-23 14:11:19
# 214897       4795061     3742188  26553351          11473 2020-03-23 14:11:47
# 214896       4795061     3742188  26553353          11473 2020-03-23 14:11:49
# 214895       4795061     3742188  26553355          11473 2020-03-23 14:11:50
# 214894       4795061     3742188  26553384          11473 2020-03-23 14:12:24
# 214893       4795061     3742188  26597615          11473 2020-03-24 16:18:49
# 214892       4795061     3742188  26624820          11473 2020-03-25 13:46:05
# 662761       4760317     3828579  26642637          11473 2020-03-26 08:03:10
# 214898       4795061     3742188  26650264          11473 2020-03-26 10:18:28
# 662760       4760317     3828579  26670178          11473 2020-03-26 16:03:29
# ...

# %%
df[(df['result_name'] == 'Резерв') & (df['position_name'] == 'Продавец-кассир')].head(10)
# df.head()
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 935549       4116220     3475232  22363108          12469 2019-09-27 12:41:52
# 935588       3968394     2969137  21326443           5955 2019-08-09 11:26:21
# 935602       3534408     3149397  18307348          36460 2019-03-13 16:38:06
# 935664       3339725     2605066  17198532          33981 2019-01-10 11:17:59
# 935701       3543652     3154483  18365076          36233 2019-03-15 16:25:38
# 935786       4102761     3467768  22264268          45851 2019-09-24 07:30:19
# 935885       4077554     2260594  22130732          30846 2019-09-18 07:45:36
# 935971       3453472     3103908  17857501          35252 2019-02-14 15:22:10
# 935982       3438032     3041035  17770406           7813 2019-02-11 10:33:21
# 936077       4034446     3428110  21787843          17857 2019-09-02 11:23:35
#
#                       stage_name                               activity_name  \
# ...

# %%
clientInfo(df, 3968394)
# Out:
#         id_applicant  id_partner    id_log  department_id         action_date  \
# 1085         3968394     2969137        -1           5955 2019-08-09 11:25:57
# 935589       3968394     2969137  21326428           5955 2019-08-09 11:26:07
# 935590       3968394     2969137  21326429           5955 2019-08-09 11:26:08
# 935588       3968394     2969137  21326443           5955 2019-08-09 11:26:21
#
#                       stage_name                       activity_name  \
# 1085          Создание кандидата                                 NaN
# 935589                 Обработка        Провести первичную обработку
# 935590                 Обработка            Проверка формы обращения
# 935588  Интервью с руководителем  Назначить интервью с руководителем
#
#        result_name
# 1085           NaN
# 935589    Подходит
# 935590   Не резерв
# 935588      Резерв

# %%
generate_unique_csv()
# Out:
#              stage_name              activity_name  \
# 0       Выход на работу
# 1       Выход на работу
# 2       Выход на работу
# 3       Выход на работу
# 4       Выход на работу
# ..                  ...                        ...
# 257  Создание кандидата
# 258       Черный список  Вывести из черного списка
# 259       Черный список  Вывести из черного списка
# 260       Черный список  Вывести из черного списка
# 261       Черный список  Вывести из черного списка
#
#                                  result_name   count
# 0                                     Принят      19
# 1    Назначить время на оформление/медосмотр       1
# 2                            Время назначено       5
# 3                            Отказ кандидата       1
# 4                                   Недозвон      18
# ..                                       ...     ...
# 257                                           683044
# 258                                              195
# ...

# %%
df[df['position_name'] != 'Продавец-кассир'].count()
# Out:
# id_applicant      0
# id_partner        0
# id_log            0
# department_id     0
# action_date       0
# stage_name        0
# activity_name     0
# result_name       0
# position_name     0
# is_open_action    0
# dtype: int64
