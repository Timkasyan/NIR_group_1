# %%
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.parser import parse

# %%
FILEPATH_2020 = "with_closed_ations_as________select_app_2020_X5_STORES.csv"
df = pd.read_csv(FILEPATH_2020)
df
# Out:
# /home/lev/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         id_applicant  id_partner  id_log  department_id  \
# 0            4797513     3847682      -1           7335
# 1            4545953     3714199      -1          24522
# 2            4600098     3714199      -1          24522
# 3            4788965     3843286      -1          10613
# 4            4777310     2372866      -1          45445
# ...              ...         ...     ...            ...
# 739676       4736341      936507      -1          32061
# 739677       4734680     2232021      -1          32061
# 739678       4782853     2753502      -1          32110
# 739679       4769924     3823657      -1          32110
# 739680       4683816      862865      -1          32093
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 739681 entries, 0 to 739680
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_applicant      739681 non-null  int64
#  1   id_partner        739681 non-null  int64
#  2   id_log            739681 non-null  int64
#  3   department_id     739681 non-null  int64
#  4   action_date       739681 non-null  object
#  5   stage_name        739681 non-null  object
#  6   activity_name     510380 non-null  object
#  7   result_name       471541 non-null  object
#  8   position_name     739681 non-null  object
#  9   is_active_action  739681 non-null  bool
#  10  is_open_action    739681 non-null  bool
# dtypes: bool(2), int64(4), object(5)
# memory usage: 52.2+ MB

# %%
df[df['position_name'] == 'Продавец-кассир']
# Out:
#         id_applicant  id_partner  id_log  department_id  \
# 0            4797513     3847682      -1           7335
# 3            4788965     3843286      -1          10613
# 4            4777310     2372866      -1          45445
# 11           4798971     1253935      -1           9851
# 13           4637426     3352131      -1           7640
# ...              ...         ...     ...            ...
# 739675       4825142     2952699      -1          32061
# 739676       4736341      936507      -1          32061
# 739678       4782853     2753502      -1          32110
# 739679       4769924     3823657      -1          32110
# 739680       4683816      862865      -1          32093
#
#                           action_date          stage_name  \
# 0       2020-03-23 19:57:25.316022+00  Создание кандидата
# 3       2020-03-20 16:09:34.454329+00  Создание кандидата
# 4       2020-03-18 13:53:36.124784+00  Создание кандидата
# ...

# %%
df = df[df['position_name'] == 'Продавец-кассир']

# %%
df
# Out:
#         id_applicant  id_partner  id_log  department_id  \
# 0            4797513     3847682      -1           7335
# 3            4788965     3843286      -1          10613
# 4            4777310     2372866      -1          45445
# 11           4798971     1253935      -1           9851
# 13           4637426     3352131      -1           7640
# ...              ...         ...     ...            ...
# 739675       4825142     2952699      -1          32061
# 739676       4736341      936507      -1          32061
# 739678       4782853     2753502      -1          32110
# 739679       4769924     3823657      -1          32110
# 739680       4683816      862865      -1          32093
#
#                           action_date          stage_name  \
# 0       2020-03-23 19:57:25.316022+00  Создание кандидата
# 3       2020-03-20 16:09:34.454329+00  Создание кандидата
# 4       2020-03-18 13:53:36.124784+00  Создание кандидата
# ...

# %%
df = df[df['is_active_action'] == True]
df
# Out:
#         id_applicant  id_partner  id_log  department_id  \
# 0            4797513     3847682      -1           7335
# 3            4788965     3843286      -1          10613
# 4            4777310     2372866      -1          45445
# 11           4798971     1253935      -1           9851
# 13           4637426     3352131      -1           7640
# ...              ...         ...     ...            ...
# 739675       4825142     2952699      -1          32061
# 739676       4736341      936507      -1          32061
# 739678       4782853     2753502      -1          32110
# 739679       4769924     3823657      -1          32110
# 739680       4683816      862865      -1          32093
#
#                           action_date          stage_name  \
# 0       2020-03-23 19:57:25.316022+00  Создание кандидата
# 3       2020-03-20 16:09:34.454329+00  Создание кандидата
# 4       2020-03-18 13:53:36.124784+00  Создание кандидата
# ...

# %%
df['stage_name'].unique()
# Out:
# array(['Создание кандидата', 'Интервью с руководителем', 'Обработка',
#        'Оформление', 'Смена вакансии', 'СБ', 'Не прошел СБ',
#        'Мы отказали', 'Выход на работу', 'Отказался', 'Резерв',
#        'Черный список'], dtype=object)

# %%
df[df['stage_name'] == 'Выход на работу']['activity_name'].unique()
# Out:
# array(['Назначить время на оформление', 'Узнать результаты приема',
#        'Предоставить обратную связь по кандидату'], dtype=object)

# %%
df[df['stage_name'] == 'Оформление']
# Out:
#         id_applicant  id_partner    id_log  department_id  \
# 214832       4799822     3848969  26663190          35752
# 214833       4799822     3848969  26651145          35752
# 214850       4813173     1155855  26686149           7676
# 214851       4813173     1155855  26685365           7676
# 214852       4813173     1155855  26674665           7676
# ...              ...         ...       ...            ...
# 739646       4859722     3757095        -1          32011
# 739647       4846458     3831915        -1          32011
# 739660       4862004     3884234        -1          31960
# 739661       4847420     3792798        -1          31960
# 739674       4858661     3882286        -1          32061
#
#                           action_date  stage_name  \
# 214832  2020-03-26 13:45:08.795075+00  Оформление
# 214833  2020-03-26 10:32:12.143249+00  Оформление
# 214850  2020-03-27 11:09:33.803032+00  Оформление
# 214851  2020-03-27 10:56:49.421809+00  Оформление
# ...

# %%
df['activity_name'].unique()
# Out:
# array([nan, 'Узнать результаты интервью с руководителем',
#        'Назначить интервью с руководителем', 'Проверка формы обращения',
#        'Провести первичную обработку',
#        'Предоставить обратную связь по кандидату',
#        'Назначить время на оформление', 'Узнать результаты СБ',
#        'Подготовить анкету кандидата', 'Узнать результаты приема',
#        'Вывести из черного списка'], dtype=object)

# %%
df['result_name'].unique()
# Out:
# array([nan, 'Отказ кандидата', 'Не резерв', 'Подходит', 'Не подходит',
#        'ОС не предоставлена руководителем', 'Отказ руководителя',
#        'Недозвон', 'Перенос звонка', 'Встреча назначена', 'Подготовлена',
#        'Резерв', 'Принят', 'ОС предоставлена руководителем',
#        'Время назначено', 'Нет обратной связи от руководителя',
#        'В белый список', 'Перенос кандидата', 'Нет обратной связи',
#        'Не принят', 'Черный список', 'Перенос руководителя',
#        'Уточнение данных'], dtype=object)

# %%
df[df['stage_name'] == 'Создание кандидата']
# Out:
#         id_applicant  id_partner  id_log  department_id  \
# 0            4797513     3847682      -1           7335
# 3            4788965     3843286      -1          10613
# 4            4777310     2372866      -1          45445
# 11           4798971     1253935      -1           9851
# 13           4637426     3352131      -1           7640
# ...              ...         ...     ...            ...
# 214796       4786698     3428147      -1          46400
# 214797       4808551     3853652      -1          23947
# 214799       4751444     3824154      -1           8990
# 214800       4687058     2940849      -1           8205
# 214801       4790888     3182834      -1          11018
#
#                           action_date          stage_name activity_name  \
# 0       2020-03-23 19:57:25.316022+00  Создание кандидата           NaN
# 3       2020-03-20 16:09:34.454329+00  Создание кандидата           NaN
# 4       2020-03-18 13:53:36.124784+00  Создание кандидата           NaN
# ...

# %%
df[df['id_applicant'] == 4797513]
# Out:
#         id_applicant  id_partner    id_log  department_id  \
# 0            4797513     3847682        -1           7335
# 589537       4797513     3847682  26637050           7335
#
#                           action_date                stage_name  \
# 0       2020-03-23 19:57:25.316022+00        Создание кандидата
# 589537  2020-03-25 16:54:00.449423+00  Интервью с руководителем
#
#                                      activity_name result_name  \
# 0                                              NaN         NaN
# 589537  Узнать результаты интервью с руководителем      Резерв
#
#           position_name  is_active_action  is_open_action
# 0       Продавец-кассир              True           False
# 589537  Продавец-кассир              True           False

# %%
df[df['id_applicant'] == 4788965]
# Out:
#         id_applicant  id_partner    id_log  department_id  \
# 3            4788965     3843286        -1          10613
# 430136       4788965     3843286  26637059          10613
#
#                           action_date                stage_name  \
# 3       2020-03-20 16:09:34.454329+00        Создание кандидата
# 430136  2020-03-25 16:54:27.086305+00  Интервью с руководителем
#
#                                      activity_name      result_name  \
# 3                                              NaN              NaN
# 430136  Узнать результаты интервью с руководителем  Отказ кандидата
#
#           position_name  is_active_action  is_open_action
# 3       Продавец-кассир              True           False
# 430136  Продавец-кассир              True           False

# %%
df[df['id_applicant'] == 4798971]
# Out:
#         id_applicant  id_partner    id_log  department_id  \
# 11           4798971     1253935        -1           9851
# 391468       4798971     1253935  26577392           9851
# 391469       4798971     1253935  26577393           9851
# 391470       4798971     1253935  26577407           9851
# 391471       4798971     1253935  26637103           9851
#
#                           action_date                stage_name  \
# 11      2020-03-24 10:39:28.667648+00        Создание кандидата
# 391468  2020-03-24 10:39:59.435347+00                 Обработка
# 391469  2020-03-24 10:40:00.474632+00                 Обработка
# 391470  2020-03-24 10:40:12.953683+00  Интервью с руководителем
# 391471         2020-03-25 16:55:18+00            Смена вакансии
#
#                              activity_name     result_name    position_name  \
# 11                                     NaN             NaN  Продавец-кассир
# ...

# %%
df[df['result_name'] == 'Подходит']
# Out:
#         id_applicant  id_partner    id_log  department_id  \
# 214808       4809171     3853922  26638907          12320
# 214837       4799096     3388458  26578035          30059
# 214854       4813173     1155855  26672396           7676
# 214855       4813173     1155855  26666888           7676
# 214858       4813173     1155855  26666900           7676
# ...              ...         ...       ...            ...
# 704659       4845662     3874498  26869895          27342
# 704663       4812837     3853722  26664880          29582
# 704665       4843263     3873116  26876167          30321
# 704668       4843263     3873116  26852456          30321
# 704671       4843263     3873116  26852452          30321
#
#                           action_date                stage_name  \
# 214808  2020-03-25 17:27:44.445276+00                 Обработка
# 214837  2020-03-24 10:53:03.196817+00                 Обработка
# 214854  2020-03-26 16:35:38.502735+00                        СБ
# ...

# %%
df[df['id_applicant'] == 4813173]
# Out:
#         id_applicant  id_partner    id_log  department_id  \
# 1899         4813173     1155855        -1           7676
# 214850       4813173     1155855  26686149           7676
# 214851       4813173     1155855  26685365           7676
# 214852       4813173     1155855  26674665           7676
# 214853       4813173     1155855  26672397           7676
# 214854       4813173     1155855  26672396           7676
# 214855       4813173     1155855  26666888           7676
# 214856       4813173     1155855  26666892           7676
# 214857       4813173     1155855  26666896           7676
# 214858       4813173     1155855  26666900           7676
# 214859       4813173     1155855  26666903           7676
#
#                           action_date                stage_name  \
# 1899    2020-03-26 14:51:48.957161+00        Создание кандидата
# 214850  2020-03-27 11:09:33.803032+00                Оформление
# 214851  2020-03-27 10:56:49.421809+00                Оформление
# ...

# %%
df['action_date'] = df['action_date'].astype(str) + "00"

# %%
df
# Out:
#         id_applicant  id_partner  id_log  department_id  \
# 0            4797513     3847682      -1           7335
# 3            4788965     3843286      -1          10613
# 4            4777310     2372866      -1          45445
# 11           4798971     1253935      -1           9851
# 13           4637426     3352131      -1           7640
# ...              ...         ...     ...            ...
# 739675       4825142     2952699      -1          32061
# 739676       4736341      936507      -1          32061
# 739678       4782853     2753502      -1          32110
# 739679       4769924     3823657      -1          32110
# 739680       4683816      862865      -1          32093
#
#                             action_date          stage_name  \
# 0       2020-03-23 19:57:25.316022+0000  Создание кандидата
# 3       2020-03-20 16:09:34.454329+0000  Создание кандидата
# 4       2020-03-18 13:53:36.124784+0000  Создание кандидата
# ...

# %%
# df['action_date'] = pd.to_datetime(df['action_date'], format="%Y-%m-%d %H:%M:%S.%f%z")

# %%
for i in range(len(df['action_date'])):
    df['action_date'][i] = parse(df['action_date'][i])
df['action_date'] = pd.to_datetime(df['action_date']).dt.strftime("%d-%m-%Y %H:%M:%S")

# %%
pd.unique(df[['stage_name', 'activity_name']].values
# Out:
#   File "<ipython-input-58-c40b5254d8c5>", line 1
#     pd.unique(df[['stage_name', 'activity_name']].values
#                                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
df_new = df[['id_applicant','stage_name','activity_name','result_name']]
df_new = df_new.sort_values('id_applicant')
df_new = df_new[df_new['stage_name'] != 'Создание кандидата']

# %%
df_new.to_csv('unique2.csv')

# %%
df_new = df[['stage_name','activity_name','result_name']]
df_new = df_new.drop_duplicates().sort_values('activity_name')

# %%
df_new.to_csv('unique.csv')

# %%
df.groupby('id_applicant').count().sort_values('action_date')
# Out:
#               id_partner  id_log  department_id  action_date  stage_name  \
# id_applicant
# 4461761                1       1              1            1           1
# 4687013                1       1              1            1           1
# 4687007                1       1              1            1           1
# 4687006                1       1              1            1           1
# 4687003                1       1              1            1           1
# ...                  ...     ...            ...          ...         ...
# 4811435               29      29             29           29          29
# 4814936               30      30             30           30          30
# 4700471               31      31             31           31          31
# 4788781               31      31             31           31          31
# 4784167               34      34             34           34          34
#
#               activity_name  result_name  position_name  is_active_action  \
# ...

# %%
# df[df['id_applicant'] == 4784167]

# %%
df
# Out:
#         id_applicant  id_partner  id_log  department_id  \
# 0            4797513     3847682      -1           7335
# 3            4788965     3843286      -1          10613
# 4            4777310     2372866      -1          45445
# 11           4798971     1253935      -1           9851
# 13           4637426     3352131      -1           7640
# ...              ...         ...     ...            ...
# 739675       4825142     2952699      -1          32061
# 739676       4736341      936507      -1          32061
# 739678       4782853     2753502      -1          32110
# 739679       4769924     3823657      -1          32110
# 739680       4683816      862865      -1          32093
#
#                           action_date          stage_name  \
# 0       2020-03-23 19:57:25.316022+00  Создание кандидата
# 3       2020-03-20 16:09:34.454329+00  Создание кандидата
# 4       2020-03-18 13:53:36.124784+00  Создание кандидата
# ...

# %%
df['action_date'] = df['action_date'].str[:19]

# %%
df
# Out:
#         id_applicant  id_partner  id_log  department_id          action_date  \
# 0            4797513     3847682      -1           7335  2020-03-23 19:57:25
# 3            4788965     3843286      -1          10613  2020-03-20 16:09:34
# 4            4777310     2372866      -1          45445  2020-03-18 13:53:36
